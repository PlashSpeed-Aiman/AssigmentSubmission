# %% [markdown]
# <a href="https://colab.research.google.com/github/PlashSpeed-Aiman/AssigmentSubmission/blob/main/1729963Assessment1_DeepLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Assessment 1: Deep Learning
#
# 1) Answer all questions.
# 2) This assessment is open-book. You are allowed to refer to any references including online materials, books, notes, codes, github links, etc.
# 3) Copy this notebook to your google drive (click **FILE** > **save a copy in Drive**)
# 4) Upload the answer notebook to your github.
# 5) Submit the assessment by sharing the link to your answer notebook.

# %% [markdown]
# **QUESTION 1**
#
# One day while wandering around a clothing store at KL East Mall, you stumbled upon a pretty girl who is choosing a dress for Hari Raya. It turns out that the girl is visually impaired and had a hard time distinguishing between an abaya and a kebaya. To help people with the similar situation, you then decided to develop an AI system to identify the type of clothes using a Convolutional Neural Networks (ConvNet). In order to train the network, you decide to use the Fashion MNIST dataset which is freely available on Pytorch.

# %% [markdown]
# a) Given the problem, what is the most appropriate loss function to use? Justify your answer. **[5 marks]**

# %% [markdown]
# <span style="color:blue;background-color: lightgrey;">
#     Cross Entropy. The loss function with minimize the distance between two probability distributions</span>

# %% [markdown]
# b) Create and train a ConvNet corresponding to the following CNN architecture (with a modification of the final layer to address the number of classes). Please include **[10 marks]**:
#
#     1) The dataloader to load the train and test datasets.
#
#     2) The model definition (either using sequential method OR pytorch class method).
#
#     3) Define your training loop.
#
#     4) Output the mean accuracy for the whole testing dataset.
#
#
#
# <div>
# <img src="https://vitalflux.com/wp-content/uploads/2021/11/VGG16-CNN-Architecture.png" width="550"/>
# </div>

# %%
import torch, torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import time
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import glob
import numpy
import random

from PIL import Image
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torchvision import datasets, models, transforms
from torchsummary import summary


###############################################
######## THE REST OF YOUR CODES HERE ##########
###############################################
image_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop((224,224)),
        transforms.RandomAutocontrast(0.3),
        transforms.Grayscale(),
        transforms.ToTensor(),
        transforms.Normalize([0.485],
                             [0.229])
    ]),
    'test': transforms.Compose([
        transforms.Resize((224,224)),
        transforms.Grayscale(),
        transforms.ToTensor(),
        transforms.Normalize([0.485],
                             [0.229])
    ])
}

# %%
batch_size = 32
trainset = torchvision.datasets.FashionMNIST(root='./data', train=True,
                                        download=True, transform=image_transforms['train'])
testset = torchvision.datasets.FashionMNIST(root='./data', train=False,
                                        download=True, transform=image_transforms['test'])

trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)

testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=2)

train_data_size = len(trainloader.dataset)
test_data_size = len(testloader.dataset)

print(train_data_size)
print(test_data_size)
# Out:
# 60000
# 10000

# %%
class My_CNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 224, 3)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(224, 112, 3)
        self.conv3 = nn.Conv2d(112, 56, 3)
        self.conv4 = nn.Conv2d(56,28, 3)
        self.conv5 = nn.Conv2d(28, 14, 3)
        self.conv6 = nn.Conv2d(14, 7, 3)
        self.fc7 = nn.Linear(7* 1*1, 4096)
        self.fc8 = nn.Linear(4096, 1000)
        self.fc9 = nn.Linear(1000, 10)
        self.relu = nn.ReLU()
    def forward(self, x):
        x = self.pool(self.relu(self.conv1(x)))
        x = self.pool(self.relu(self.conv2(x)))
        x = self.pool(self.relu(self.conv3(x)))
        x = self.pool(self.relu(self.conv4(x)))
        x = self.pool(self.relu(self.conv5(x)))
        x = self.pool(self.relu(self.conv6(x)))
        # print(x.shape)
        x = x.view(-1,7 *1 * 1)
        x = self.relu(self.fc7(x))
        x = self.relu(self.fc8(x))
        x = self.relu(self.fc9(x))
        return x
model = My_CNN()

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# 3. move the model to GPU
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
model.to(device)
# Out:
# My_CNN(
#   (conv1): Conv2d(1, 224, kernel_size=(3, 3), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(224, 112, kernel_size=(3, 3), stride=(1, 1))
#   (conv3): Conv2d(112, 56, kernel_size=(3, 3), stride=(1, 1))
#   (conv4): Conv2d(56, 28, kernel_size=(3, 3), stride=(1, 1))
#   (conv5): Conv2d(28, 14, kernel_size=(3, 3), stride=(1, 1))
#   (conv6): Conv2d(14, 7, kernel_size=(3, 3), stride=(1, 1))
#   (fc7): Linear(in_features=7, out_features=4096, bias=True)
#   (fc8): Linear(in_features=4096, out_features=1000, bias=True)
#   (fc9): Linear(in_features=1000, out_features=10, bias=True)
#   (relu): ReLU()
# )

# %%
import time # to calculate training time

def train_and_validate(model, loss_criterion, optimizer, epochs=25):
    '''
    Function to train and validate
    Parameters
        :param model: Model to train and validate
        :param loss_criterion: Loss Criterion to minimize
        :param optimizer: Optimizer for computing gradients
        :param epochs: Number of epochs (default=25)
  
    Returns
        model: Trained Model with best validation accuracy
        history: (dict object): Having training loss, accuracy and validation loss, accuracy
    '''
    
    start = time.time()
    history = []
    best_acc = 0.0

    for epoch in range(epochs):
        epoch_start = time.time()
        print("Epoch: {}/{}".format(epoch+1, epochs))
        
        # Set to training mode
        model.train()
        
        # Loss and Accuracy within the epoch
        train_loss = 0.0
        train_acc = 0.0
        
        valid_loss = 0.0
        valid_acc = 0.0
        
        for i, (inputs, labels) in enumerate(trainloader):

            inputs = inputs.to(device)
            labels = labels.to(device)
            
            # Clean existing gradients
            optimizer.zero_grad()
            
            # Forward pass - compute outputs on input data using the model
            outputs = model(inputs)
            
            # Compute loss
            loss = loss_criterion(outputs, labels)
            
            # Backpropagate the gradients
            loss.backward()
            
            # Update the parameters
            optimizer.step()
            
            # Compute the total loss for the batch and add it to train_loss
            train_loss += loss.item() * inputs.size(0)
            
            # Compute the accuracy
            ret, predictions = torch.max(outputs.data, 1)
            correct_counts = predictions.eq(labels.data.view_as(predictions))
            
            # Convert correct_counts to float and then compute the mean
            acc = torch.mean(correct_counts.type(torch.FloatTensor))
            
            # Compute total accuracy in the whole batch and add to train_acc
            train_acc += acc.item() * inputs.size(0)
            
            #print("Batch number: {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}".format(i, loss.item(), acc.item()))

            
        # Validation - No gradient tracking needed
        with torch.no_grad():

            # Set to evaluation mode
            model.eval()

            # Validation loop
            for j, (inputs, labels) in enumerate(testloader):
                inputs = inputs.to(device)
                labels = labels.to(device)

                # Forward pass - compute outputs on input data using the model
                outputs = model(inputs)

                # Compute loss
                loss = loss_criterion(outputs, labels)

                # Compute the total loss for the batch and add it to valid_loss
                valid_loss += loss.item() * inputs.size(0)

                # Calculate validation accuracy
                ret, predictions = torch.max(outputs.data, 1)
                correct_counts = predictions.eq(labels.data.view_as(predictions))

                # Convert correct_counts to float and then compute the mean
                acc = torch.mean(correct_counts.type(torch.FloatTensor))

                # Compute total accuracy in the whole batch and add to valid_acc
                valid_acc += acc.item() * inputs.size(0)

                #print("Validation Batch number: {:03d}, Validation: Loss: {:.4f}, Accuracy: {:.4f}".format(j, loss.item(), acc.item()))
            
        # Find average training loss and training accuracy
        avg_train_loss = train_loss/train_data_size 
        avg_train_acc = train_acc/train_data_size

        # Find average training loss and training accuracy
        avg_test_loss = valid_loss/test_data_size 
        avg_test_acc = valid_acc/test_data_size

        history.append([avg_train_loss, avg_test_loss, avg_train_acc, avg_test_acc])
                
        epoch_end = time.time()
    
        print("Epoch : {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}%, \n\t\tValidation : Loss : {:.4f}, Accuracy: {:.4f}%, Time: {:.4f}s".format(epoch, avg_train_loss, avg_train_acc*100, avg_test_loss, avg_test_acc*100, epoch_end-epoch_start))
        
        # Save if the model has best accuracy till now
        torch.save(model, 'cifar10_model_'+str(epoch)+'.pt')
            
    return model, history

# %%
num_epochs = 5
trained_model, history = train_and_validate(model, criterion, optimizer, num_epochs)
# Out:
# Epoch: 1/5
# Epoch : 000, Training: Loss: 2.3026, Accuracy: 10.0067%,
# 		Validation : Loss : 2.3026, Accuracy: 10.0000%, Time: 480.4513s
# Epoch: 2/5
# Epoch : 001, Training: Loss: 2.3026, Accuracy: 10.0000%,
# 		Validation : Loss : 2.3026, Accuracy: 10.0000%, Time: 482.6988s
# Epoch: 3/5
# Epoch : 002, Training: Loss: 2.3026, Accuracy: 10.0000%,
# 		Validation : Loss : 2.3026, Accuracy: 10.0000%, Time: 482.4978s
# Epoch: 4/5
# Epoch : 003, Training: Loss: 2.3026, Accuracy: 10.0000%,
# 		Validation : Loss : 2.3026, Accuracy: 10.0000%, Time: 482.6511s
# Epoch: 5/5
# Epoch : 004, Training: Loss: 2.3026, Accuracy: 10.0000%,
# 		Validation : Loss : 2.3026, Accuracy: 10.0000%, Time: 482.5158s

# %% [markdown]
# <b>Model is takes too long to train</b>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# c) Replace your defined CNN in b) with a pre-trained model. Then, proceed with a transfer learning and finetune the model for the Fashion MNIST dataset. **[10 marks]**

# %%
# %cd /content/drive/MyDrive/Esesmeng_Baju_Dataset
# Out:
# /content/drive/MyDrive/Esesmeng_Baju_Dataset

# %%
from torchvision.transforms.transforms import Grayscale
###############################################
###############YOUR CODES HERE ################
###############################################
image_transforms = {
    'train': transforms.Compose([
        # transforms.RandomResizedCrop((224,224)),
        transforms.RandomAutocontrast(0.3),
        transforms.Grayscale(3),
        transforms.ToTensor(),
        transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])

    ]),
    'test': transforms.Compose([
        # transforms.Resize((224,224)),
        transforms.Grayscale(3),
        transforms.ToTensor(),
        transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
    ])
}
batch_size = 32
trainset = torchvision.datasets.FashionMNIST(root='./data', train=True,
                                        download=True, transform=image_transforms['train'])
testset = torchvision.datasets.FashionMNIST(root='./data', train=False,
                                        download=True, transform=image_transforms['test'])

trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)

testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=2)

train_data_size = len(trainloader.dataset)
test_data_size = len(testloader.dataset)

print(train_data_size)
print(test_data_size)
# Out:
# 60000
# 10000

# %%
import time # to calculate training time

def train_and_validate(model, loss_criterion, optimizer, epochs=25):
    '''
    Function to train and validate
    Parameters
        :param model: Model to train and validate
        :param loss_criterion: Loss Criterion to minimize
        :param optimizer: Optimizer for computing gradients
        :param epochs: Number of epochs (default=25)
  
    Returns
        model: Trained Model with best validation accuracy
        history: (dict object): Having training loss, accuracy and validation loss, accuracy
    '''
    
    start = time.time()
    history = []
    best_acc = 0.0

    for epoch in range(epochs):
        epoch_start = time.time()
        print("Epoch: {}/{}".format(epoch+1, epochs))
        
        # Set to training mode
        model.train()
        
        # Loss and Accuracy within the epoch
        train_loss = 0.0
        train_acc = 0.0
        
        valid_loss = 0.0
        valid_acc = 0.0
        
        for i, (inputs, labels) in enumerate(trainloader):

            inputs = inputs.to(device)
            labels = labels.to(device)
            
            # Clean existing gradients
            optimizer.zero_grad()
            
            # Forward pass - compute outputs on input data using the model
            outputs = model(inputs)
            
            # Compute loss
            loss = loss_criterion(outputs, labels)
            
            # Backpropagate the gradients
            loss.backward()
            
            # Update the parameters
            optimizer.step()
            
            # Compute the total loss for the batch and add it to train_loss
            train_loss += loss.item() * inputs.size(0)
            
            # Compute the accuracy
            ret, predictions = torch.max(outputs.data, 1)
            correct_counts = predictions.eq(labels.data.view_as(predictions))
            
            # Convert correct_counts to float and then compute the mean
            acc = torch.mean(correct_counts.type(torch.FloatTensor))
            
            # Compute total accuracy in the whole batch and add to train_acc
            train_acc += acc.item() * inputs.size(0)
            
            #print("Batch number: {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}".format(i, loss.item(), acc.item()))

            
        # Validation - No gradient tracking needed
        with torch.no_grad():

            # Set to evaluation mode
            model.eval()

            # Validation loop
            for j, (inputs, labels) in enumerate(testloader):
                inputs = inputs.to(device)
                labels = labels.to(device)

                # Forward pass - compute outputs on input data using the model
                outputs = model(inputs)

                # Compute loss
                loss = loss_criterion(outputs, labels)

                # Compute the total loss for the batch and add it to valid_loss
                valid_loss += loss.item() * inputs.size(0)

                # Calculate validation accuracy
                ret, predictions = torch.max(outputs.data, 1)
                correct_counts = predictions.eq(labels.data.view_as(predictions))

                # Convert correct_counts to float and then compute the mean
                acc = torch.mean(correct_counts.type(torch.FloatTensor))

                # Compute total accuracy in the whole batch and add to valid_acc
                valid_acc += acc.item() * inputs.size(0)

                #print("Validation Batch number: {:03d}, Validation: Loss: {:.4f}, Accuracy: {:.4f}".format(j, loss.item(), acc.item()))
            
        # Find average training loss and training accuracy
        avg_train_loss = train_loss/train_data_size 
        avg_train_acc = train_acc/train_data_size

        # Find average training loss and training accuracy
        avg_test_loss = valid_loss/test_data_size 
        avg_test_acc = valid_acc/test_data_size

        history.append([avg_train_loss, avg_test_loss, avg_train_acc, avg_test_acc])
                
        epoch_end = time.time()
    
        print("Epoch : {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}%, \n\t\tValidation : Loss : {:.4f}, Accuracy: {:.4f}%, Time: {:.4f}s".format(epoch, avg_train_loss, avg_train_acc*100, avg_test_loss, avg_test_acc*100, epoch_end-epoch_start))
        
        # Save if the model has best accuracy till now
        torch.save(model, 'cifar10_model_'+str(epoch)+'.pt')
            
    return model, history

# %%
model_ftc
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
num_ftrs
# Out:
# 512

# %%
model_ftc = models.resnet18(pretrained = True)
num_ftrs = model_ftc.fc.in_features
model_ftc.fc = nn.Linear(num_ftrs, 10)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model_ftc.parameters(), lr=0.0001, momentum=0.9)
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
model_ftc.to(device)
print('Running on device: {}'.format(device))
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Running on device: cuda:0

# %%
class_names = trainset.classes
class_names
# Out:
# ['T-shirt/top',
#  'Trouser',
#  'Pullover',
#  'Dress',
#  'Coat',
#  'Sandal',
#  'Shirt',
#  'Sneaker',
#  'Bag',
#  'Ankle boot']

# %%
num_epochs = 10
trained_model, history = train_and_validate(model_ftc, criterion, optimizer, num_epochs)
# Out:
# Epoch: 1/10
# Epoch : 000, Training: Loss: 0.6556, Accuracy: 77.5950%,
# 		Validation : Loss : 0.3919, Accuracy: 86.0100%, Time: 47.7912s
# Epoch: 2/10
# Epoch : 001, Training: Loss: 0.4000, Accuracy: 85.7750%,
# 		Validation : Loss : 0.3284, Accuracy: 88.1600%, Time: 45.4146s
# Epoch: 3/10
# Epoch : 002, Training: Loss: 0.3332, Accuracy: 88.1333%,
# 		Validation : Loss : 0.3056, Accuracy: 89.1600%, Time: 45.8127s
# Epoch: 4/10
# Epoch : 003, Training: Loss: 0.3002, Accuracy: 89.3233%,
# 		Validation : Loss : 0.2962, Accuracy: 89.2700%, Time: 44.7841s
# Epoch: 5/10
# Epoch : 004, Training: Loss: 0.2767, Accuracy: 90.1450%,
# 		Validation : Loss : 0.2809, Accuracy: 90.0100%, Time: 45.8806s
# Epoch: 6/10
# Epoch : 005, Training: Loss: 0.2545, Accuracy: 90.9617%,
# 		Validation : Loss : 0.2684, Accuracy: 90.3500%, Time: 44.4548s
# Epoch: 7/10
# Epoch : 006, Training: Loss: 0.2376, Accuracy: 91.4250%,
# 		Validation : Loss : 0.2655, Accuracy: 90.4300%, Time: 45.7056s
# Epoch: 8/10
# Epoch : 007, Training: Loss: 0.2237, Accuracy: 91.9183%,
# 		Validation : Loss : 0.2636, Accuracy: 90.5400%, Time: 44.8374s
# Epoch: 9/10
# Epoch : 008, Training: Loss: 0.2112, Accuracy: 92.3817%,
# 		Validation : Loss : 0.2602, Accuracy: 90.8200%, Time: 46.1669s
# Epoch: 10/10
# Epoch : 009, Training: Loss: 0.1990, Accuracy: 92.8100%,
# 		Validation : Loss : 0.2548, Accuracy: 90.8700%, Time: 45.0217s

# %% [markdown]
# d) Using model-centric methods, propose two (2) strategies that can be used to increase the accuracy of the model on the testing dataset. **[5 marks]**
#
#
# <span style="color:blue">
#     Two model-centric techniques that I propose are:
#     1)Batch Normalization
#     2)Dropout
#     </span>

# %% [markdown]
# e) Next, implement the two proposed model-centric techniques for the same problem as in the previous question. **[15 marks]**

# %%
###############################################
###############YOUR CODES HERE ################
###############################################

# %%
import torch, torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import time
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import glob
import numpy
import random

from PIL import Image
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torchvision import datasets, models, transforms
from torchsummary import summary


###############################################
######## THE REST OF YOUR CODES HERE ##########
###############################################
image_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop((224,224)),
        transforms.RandomAutocontrast(0.3),
        transforms.Grayscale(3),
        transforms.ToTensor(),
        transforms.Normalize([0.485],
                             [0.229])
    ]),
    'test': transforms.Compose([
        transforms.Resize((224,224)),
        transforms.Grayscale(3),
        transforms.ToTensor(),
        transforms.Normalize([0.485],
                             [0.229])
    ])
}

# %%
batch_size = 32
trainset = torchvision.datasets.FashionMNIST(root='./data', train=True,
                                        download=True, transform=image_transforms['train'])
testset = torchvision.datasets.FashionMNIST(root='./data', train=False,
                                        download=True, transform=image_transforms['test'])

trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)

testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=2)

train_data_size = len(trainloader.dataset)
test_data_size = len(testloader.dataset)

print(train_data_size)
print(test_data_size)
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/26421880 [00:00<?, ?it/s]
# Extracting ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/29515 [00:00<?, ?it/s]
# Extracting ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/4422102 [00:00<?, ?it/s]
# Extracting ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/5148 [00:00<?, ?it/s]
# Extracting ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
#
# 60000
# 10000

# %%
class MyCustomModel(nn.Module):
    def __init__(self, pretrained=True):
        super().__init__()
        
     

        resnet18 = models.resnet18(pretrained=pretrained)
        self.features = nn.ModuleList(resnet18.children())[:-1]
        self.features = nn.Sequential(*self.features)
        in_features = resnet18.fc.in_features

        self.fc0 = nn.Linear(in_features, 256)
        self.bn1 = nn.BatchNorm1d(256, eps = 1e-2)
        self.fc1 = nn.Linear(256, 64)
        self.bn2 = nn.BatchNorm1d(64, eps = 1e-2)
        self.dp = nn.Dropout (0.4)
        self.classifier = nn.Linear(64, 10)
        self.relu = nn.ReLU()
        
        for m in self.modules():
            if isinstance(m, nn.Linear):
                torch.nn.init.xavier_normal_(m.weight, gain = 1)

    def forward(self, input_imgs):
        output = self.features(input_imgs)
        output = output.view(input_imgs.size(0), -1)
       # and also our new layers. 
        output = self.relu(self.fc0(output))
        output = self.dp(self.bn2(self.relu(self.fc1(output))))
        output = self.classifier(output)
                
        return output
    
model = MyCustomModel()
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# 3. move the model to GPU
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
model.to(device)
# Out:
# MyCustomModel(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (8): AdaptiveAvgPool2d(output_size=(1, 1))
#   )
#   (fc0): Linear(in_features=512, out_features=256, bias=True)
#   (bn1): BatchNorm1d(256, eps=0.01, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=256, out_features=64, bias=True)
#   (bn2): BatchNorm1d(64, eps=0.01, momentum=0.1, affine=True, track_running_stats=True)
#   (dp): Dropout(p=0.4, inplace=False)
#   (classifier): Linear(in_features=64, out_features=10, bias=True)
#   (relu): ReLU()
# )

# %%
import time # to calculate training time

def train_and_validate(model, loss_criterion, optimizer, epochs=25):
    '''
    Function to train and validate
    Parameters
        :param model: Model to train and validate
        :param loss_criterion: Loss Criterion to minimize
        :param optimizer: Optimizer for computing gradients
        :param epochs: Number of epochs (default=25)
  
    Returns
        model: Trained Model with best validation accuracy
        history: (dict object): Having training loss, accuracy and validation loss, accuracy
    '''
    
    start = time.time()
    history = []
    best_acc = 0.0

    for epoch in range(epochs):
        epoch_start = time.time()
        print("Epoch: {}/{}".format(epoch+1, epochs))
        
        # Set to training mode
        model.train()
        
        # Loss and Accuracy within the epoch
        train_loss = 0.0
        train_acc = 0.0
        
        valid_loss = 0.0
        valid_acc = 0.0
        
        for i, (inputs, labels) in enumerate(trainloader):

            inputs = inputs.to(device)
            labels = labels.to(device)
            
            # Clean existing gradients
            optimizer.zero_grad()
            
            # Forward pass - compute outputs on input data using the model
            outputs = model(inputs)
            
            # Compute loss
            loss = loss_criterion(outputs, labels)
            
            # Backpropagate the gradients
            loss.backward()
            
            # Update the parameters
            optimizer.step()
            
            # Compute the total loss for the batch and add it to train_loss
            train_loss += loss.item() * inputs.size(0)
            
            # Compute the accuracy
            ret, predictions = torch.max(outputs.data, 1)
            correct_counts = predictions.eq(labels.data.view_as(predictions))
            
            # Convert correct_counts to float and then compute the mean
            acc = torch.mean(correct_counts.type(torch.FloatTensor))
            
            # Compute total accuracy in the whole batch and add to train_acc
            train_acc += acc.item() * inputs.size(0)
            
            #print("Batch number: {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}".format(i, loss.item(), acc.item()))

            
        # Validation - No gradient tracking needed
        with torch.no_grad():

            # Set to evaluation mode
            model.eval()

            # Validation loop
            for j, (inputs, labels) in enumerate(testloader):
                inputs = inputs.to(device)
                labels = labels.to(device)

                # Forward pass - compute outputs on input data using the model
                outputs = model(inputs)

                # Compute loss
                loss = loss_criterion(outputs, labels)

                # Compute the total loss for the batch and add it to valid_loss
                valid_loss += loss.item() * inputs.size(0)

                # Calculate validation accuracy
                ret, predictions = torch.max(outputs.data, 1)
                correct_counts = predictions.eq(labels.data.view_as(predictions))

                # Convert correct_counts to float and then compute the mean
                acc = torch.mean(correct_counts.type(torch.FloatTensor))

                # Compute total accuracy in the whole batch and add to valid_acc
                valid_acc += acc.item() * inputs.size(0)

                #print("Validation Batch number: {:03d}, Validation: Loss: {:.4f}, Accuracy: {:.4f}".format(j, loss.item(), acc.item()))
            
        # Find average training loss and training accuracy
        avg_train_loss = train_loss/train_data_size 
        avg_train_acc = train_acc/train_data_size

        # Find average training loss and training accuracy
        avg_test_loss = valid_loss/test_data_size 
        avg_test_acc = valid_acc/test_data_size

        history.append([avg_train_loss, avg_test_loss, avg_train_acc, avg_test_acc])
                
        epoch_end = time.time()
    
        print("Epoch : {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}%, \n\t\tValidation : Loss : {:.4f}, Accuracy: {:.4f}%, Time: {:.4f}s".format(epoch, avg_train_loss, avg_train_acc*100, avg_test_loss, avg_test_acc*100, epoch_end-epoch_start))
        
        # Save if the model has best accuracy till now
        torch.save(model, 'cifar10_model_'+str(epoch)+'.pt')
            
    return model, history

# %%
num_epochs = 10
trained_model, history = train_and_validate(model, criterion, optimizer, num_epochs)
# Out:
# Epoch: 1/10
# Epoch : 000, Training: Loss: 0.8531, Accuracy: 70.8317%,
# 		Validation : Loss : 0.3250, Accuracy: 88.6400%, Time: 210.3624s
# Epoch: 2/10
# Epoch : 001, Training: Loss: 0.6071, Accuracy: 79.0117%,
# 		Validation : Loss : 0.3356, Accuracy: 88.8100%, Time: 208.3572s
# Epoch: 3/10
# Epoch : 002, Training: Loss: 0.5428, Accuracy: 81.1600%,
# 		Validation : Loss : 0.2561, Accuracy: 90.8600%, Time: 205.8620s
# Epoch: 4/10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-e189953a27c7> in <module>()
#       1 num_epochs = 10
# ----> 2 trained_model, history = train_and_validate(model, criterion, optimizer, num_epochs)
#
# <ipython-input-6-8d62a2b162a6> in train_and_validate(model, loss_criterion, optimizer, epochs)
#      33         valid_acc = 0.0
#      34
# ---> 35         for i, (inputs, labels) in enumerate(trainloader):
#      36
#      37             inputs = inputs.to(device)
#
# KeyboardInterrupt:

# %% [markdown]
# f) Do you see any accuracy improvement? Whether it is a "yes" or "no", discuss the possible reasons contributing to the accuracy improvement/ unimprovement. **[5 marks]**
#
# <span style="color:blue">
#     Yes. A noticible improvment. Batch Norm and Dropout skips a few layers and as an effect, increase accuracy</span>

# %% [markdown]
# g) In real applications, data-centric strategies are essential to train robust deep learning models. Give two (2) examples of such strategies and discuss how the strategies helps improving the model accuracy. **[5 marks]**
#
# <span style="color:blue">
#     1) Clean Data
#     2) Do Data Transformation </span>

# %% [markdown]
# h) Next, implement the two proposed data-centric techniques for the same problem as in the previous question. **[10 marks]**

# %%
###############################################
##############YOUR CODES HERE #################
###############################################
image_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop((224,224)),
        transforms.RandomAutocontrast(0.3),
        transforms.Grayscale(3),
        transforms.ToTensor(),
        transforms.Normalize([0.485],
                             [0.229])
    ]),
    'test': transforms.Compose([
        transforms.Resize((224,224)),
        transforms.Grayscale(3),
        transforms.ToTensor(),
        transforms.Normalize([0.485],
                             [0.229])
    ])
}

# %% [markdown]
# **QUESTION 2** **[35 marks]**
#
# Firstly, watch this video:
#
# https://drive.google.com/file/d/1bsypahR7I3f_R3DXkfw_tf0BrbCHxE_O/view?usp=sharing
#
# This video shows an example of masked face recognition where the deep learning model is able to detect and classify your face even when wearing a face mask. Using the end-to-end object detection pipeline that you have learned, develop your own masked face recognition such that the model should recognize your face even on face mask while recognize other persons as "others".
#
# Deliverables for this question are:
#
# - the model file. Change the name to <your_name>.pt file (e.g. hasan.pt).
# - a short video (~10 secs) containing your face and your friends faces (for inference).

# %%
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting roboflow
#   Downloading roboflow-0.2.11-py3-none-any.whl (28 kB)
# Requirement already satisfied: idna==2.10 in /usr/local/lib/python3.7/dist-packages (from roboflow) (2.10)
# Collecting kiwisolver==1.3.1
#   Downloading kiwisolver-1.3.1-cp37-cp37m-manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 38.0 MB/s
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.7/dist-packages (from roboflow) (4.64.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.7/dist-packages (from roboflow) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from roboflow) (2.23.0)
# Collecting python-dotenv
#   Downloading python_dotenv-0.20.0-py3-none-any.whl (17 kB)
# Collecting opencv-python-headless==4.2.0.32
#   Downloading opencv_python_headless-4.2.0.32-cp37-cp37m-manylinux1_x86_64.whl (21.6 MB)
#      |████████████████████████████████| 21.6 MB 1.5 MB/s
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from roboflow) (2.8.2)
# Collecting urllib3==1.26.6
#   Downloading urllib3-1.26.6-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 59.0 MB/s
# Collecting certifi==2021.5.30
#   Downloading certifi-2021.5.30-py2.py3-none-any.whl (145 kB)
#      |████████████████████████████████| 145 kB 71.7 MB/s
# Collecting Pillow==9.0.1
#   Downloading Pillow-9.0.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 44.8 MB/s
# Collecting requests-toolbelt
#   Downloading requests_toolbelt-0.9.1-py2.py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 1.1 MB/s
# Collecting PyYAML>=5.3.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 61.3 MB/s
# Collecting cycler==0.10.0
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.7/dist-packages (from roboflow) (7.1.2)
# Collecting pyparsing==2.4.7
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 2.7 MB/s
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
# Requirement already satisfied: glob2 in /usr/local/lib/python3.7/dist-packages (from roboflow) (0.7)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from roboflow) (3.2.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from roboflow) (1.15.0)
# Collecting chardet==4.0.0
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#      |████████████████████████████████| 178 kB 47.7 MB/s
# Collecting requests
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 493 kB/s
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests->roboflow) (2.1.0)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=e636a9077a773f9adda9e905c5fcec0af7e2eca29b33520c693f82e474f65215
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built wget
# Installing collected packages: urllib3, certifi, requests, pyparsing, kiwisolver, cycler, wget, requests-toolbelt, PyYAML, python-dotenv, opencv-python-headless, chardet, roboflow
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2022.6.15
#     Uninstalling certifi-2022.6.15:
#       Successfully uninstalled certifi-2022.6.15
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: kiwisolver
#     Found existing installation: kiwisolver 1.4.4
#     Uninstalling kiwisolver-1.4.4:
#       Successfully uninstalled kiwisolver-1.4.4
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.11.0
#     Uninstalling cycler-0.11.0:
#       Successfully uninstalled cycler-0.11.0
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: chardet
#     Found existing installation: chardet 3.0.4
#     Uninstalling chardet-3.0.4:
#       Successfully uninstalled chardet-3.0.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.28.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# roboflow 0.2.11 requires Pillow==9.0.1, but you have pillow 7.1.2 which is incompatible.
# Successfully installed PyYAML-6.0 certifi-2021.5.30 chardet-4.0.0 cycler-0.10.0 kiwisolver-1.3.1 opencv-python-headless-4.2.0.32 pyparsing-2.4.7 python-dotenv-0.20.0 requests-2.28.1 requests-toolbelt-0.9.1 roboflow-0.2.11 urllib3-1.26.6 wget-3.2
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in MukaMukaBarai-1 to yolov5pytorch: 100% [6954627 / 6954627] bytes
# Extracting Dataset Version Zip to MukaMukaBarai-1 in yolov5pytorch:: 100%|██████████| 600/600 [00:00<00:00, 1856.71it/s]

# %%
#clone YOLOv5 and 
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="B6Px5weSyUj1LpkxMCdH")
project = rf.workspace("dlcv-9281y").project("mukamukabarai")
dataset = project.version(1).download("yolov5")
import torch
import os
from IPython.display import Image, clear_output  # to display images
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12351, done.
# remote: Counting objects: 100% (133/133), done.
# remote: Compressing objects: 100% (87/87), done.
# remote: Total 12351 (delta 77), reused 89 (delta 46), pack-reused 12218
# Receiving objects: 100% (12351/12351), 12.35 MiB | 18.20 MiB/s, done.
# Resolving deltas: 100% (8446/8446), done.
# /content/yolov5/yolov5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: roboflow in /usr/local/lib/python3.7/dist-packages (0.2.11)
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.7/dist-packages (from roboflow) (4.0.0)
# Requirement already satisfied: certifi==2021.5.30 in /usr/local/lib/python3.7/dist-packages (from roboflow) (2021.5.30)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from roboflow) (2.28.1)
# Requirement already satisfied: cycler==0.10.0 in /usr/local/lib/python3.7/dist-packages (from roboflow) (0.10.0)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.7/dist-packages (from roboflow) (9.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from roboflow) (1.15.0)
# Requirement already satisfied: idna==2.10 in /usr/local/lib/python3.7/dist-packages (from roboflow) (2.10)
# Requirement already satisfied: glob2 in /usr/local/lib/python3.7/dist-packages (from roboflow) (0.7)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from roboflow) (2.8.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from roboflow) (3.2.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.7/dist-packages (from roboflow) (1.21.6)
# Requirement already satisfied: pyparsing==2.4.7 in /usr/local/lib/python3.7/dist-packages (from roboflow) (2.4.7)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.7/dist-packages (from roboflow) (0.20.0)
# Requirement already satisfied: opencv-python-headless==4.2.0.32 in /usr/local/lib/python3.7/dist-packages (from roboflow) (4.2.0.32)
# Requirement already satisfied: kiwisolver==1.3.1 in /usr/local/lib/python3.7/dist-packages (from roboflow) (1.3.1)
# Requirement already satisfied: wget in /usr/local/lib/python3.7/dist-packages (from roboflow) (3.2)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.7/dist-packages (from roboflow) (0.9.1)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.7/dist-packages (from roboflow) (4.64.0)
# Requirement already satisfied: urllib3==1.26.6 in /usr/local/lib/python3.7/dist-packages (from roboflow) (1.26.6)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.7/dist-packages (from roboflow) (6.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests->roboflow) (2.1.0)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in /content/yolov5/MukaMukaBarai-1/MukaMukaBarai-1 to yolov5pytorch: 100% [6954627 / 6954627] bytes
# Extracting Dataset Version Zip to /content/yolov5/MukaMukaBarai-1/MukaMukaBarai-1 in yolov5pytorch:: 100%|██████████| 600/600 [00:00<00:00, 1412.47it/s]

# %%
os.environ["DATASET_DIRECTORY"] = "/content/yolov5/MukaMukaBarai-1"

# %%
# !python train.py --img 416 --batch 16 --epochs 150 --data {dataset.location}/data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/yolov5/MukaMukaBarai-1/MukaMukaBarai-1/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=150, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-347-g7b9cc32 Python-3.7.13 torch-1.12.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5 🚀 runs (RECOMMENDED)
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 124MB/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v6.1/yolov5s.pt to yolov5s.pt...
# 100% 14.1M/14.1M [00:00<00:00, 293MB/s]
#
# Overriding model.yaml nc=80 with nc=2
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     18879  models.yolo.Detect                      [2, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 270 layers, 7025023 parameters, 7025023 gradients, 16.0 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# AMP: checks passed ✅
# Scaled weight_decay = 0.0005
# optimizer: SGD with parameter groups 57 weight (no decay), 60 weight, 60 bias
# albumentations: version 1.0.3 required by YOLOv5, but version 0.1.12 is currently installed
# train: Scanning '/content/yolov5/MukaMukaBarai-1/MukaMukaBarai-1/train/labels' images and labels...256 found, 0 missing, 0 empty, 0 corrupt: 100% 256/256 [00:00<00:00, 2153.78it/s]
# train: New cache created: /content/yolov5/MukaMukaBarai-1/MukaMukaBarai-1/train/labels.cache
# train: Caching images (0.1GB ram): 100% 256/256 [00:00<00:00, 417.52it/s]
# val: Scanning '/content/yolov5/MukaMukaBarai-1/MukaMukaBarai-1/valid/labels' images and labels...25 found, 0 missing, 0 empty, 0 corrupt: 100% 25/25 [00:00<00:00, 677.13it/s]
# val: New cache created: /content/yolov5/MukaMukaBarai-1/MukaMukaBarai-1/valid/labels.cache
# val: Caching images (0.0GB ram): 100% 25/25 [00:00<00:00, 163.04it/s]
# Plotting labels to runs/train/exp/labels.jpg...
#
# AutoAnchor: 4.71 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Image sizes 416 train, 416 val
# Using 2 dataloader workers
# Logging results to runs/train/exp
# Starting training for 150 epochs...
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      0/149     1.71G    0.1106   0.02287   0.03052        41       416: 100% 16/16 [00:06<00:00,  2.29it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:01<00:00,  1.49s/it]
#                  all         25         51    0.00451      0.787     0.0096    0.00244
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      1/149     1.91G   0.08236   0.03004   0.02452        42       416: 100% 16/16 [00:02<00:00,  6.74it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  3.77it/s]
#                  all         25         51     0.0354      0.688     0.0659     0.0265
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      2/149     1.91G   0.06713   0.02949   0.02035        43       416: 100% 16/16 [00:02<00:00,  7.06it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.78it/s]
#                  all         25         51      0.193      0.405      0.215     0.0629
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      3/149     1.91G   0.06468   0.02586   0.01654        49       416: 100% 16/16 [00:02<00:00,  7.01it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.26it/s]
#                  all         25         51      0.296      0.361      0.359      0.151
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      4/149     1.91G   0.06743   0.02201   0.01434        38       416: 100% 16/16 [00:02<00:00,  7.19it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.41it/s]
#                  all         25         51      0.123       0.27      0.108     0.0315
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      5/149     1.91G   0.06892   0.02209   0.01151        37       416: 100% 16/16 [00:02<00:00,  7.08it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.57it/s]
#                  all         25         51      0.431      0.692      0.437      0.196
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      6/149     1.91G   0.06743   0.02084  0.007969        41       416: 100% 16/16 [00:02<00:00,  7.31it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.87it/s]
#                  all         25         51      0.604      0.721      0.545      0.215
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      7/149     1.91G   0.06502   0.01923  0.005263        40       416: 100% 16/16 [00:02<00:00,  7.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.94it/s]
#                  all         25         51      0.711      0.698       0.59      0.231
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      8/149     1.91G    0.0547    0.0197  0.004986        49       416: 100% 16/16 [00:02<00:00,  7.33it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.16it/s]
#                  all         25         51      0.836      0.799      0.839       0.35
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      9/149     1.91G   0.05333    0.0188  0.003825        50       416: 100% 16/16 [00:02<00:00,  7.23it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.94it/s]
#                  all         25         51      0.509      0.875      0.751      0.304
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     10/149     1.91G   0.05282   0.01824  0.002846        44       416: 100% 16/16 [00:02<00:00,  7.27it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.07it/s]
#                  all         25         51      0.629      0.751      0.698      0.331
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     11/149     1.91G   0.04522    0.0184  0.003065        50       416: 100% 16/16 [00:02<00:00,  7.22it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.20it/s]
#                  all         25         51      0.731       0.71      0.727      0.282
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     12/149     1.91G   0.04598   0.01607  0.002461        44       416: 100% 16/16 [00:02<00:00,  7.37it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.85it/s]
#                  all         25         51      0.741       0.72      0.852      0.438
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     13/149     1.91G   0.04549    0.0179  0.002325        53       416: 100% 16/16 [00:02<00:00,  7.30it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.11it/s]
#                  all         25         51      0.853       0.88      0.883      0.365
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     14/149     1.91G   0.04426   0.01686  0.002044        52       416: 100% 16/16 [00:02<00:00,  5.96it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.05it/s]
#                  all         25         51      0.636      0.834      0.769      0.308
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     15/149     1.91G    0.0408   0.01622  0.001771        49       416: 100% 16/16 [00:02<00:00,  7.23it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.98it/s]
#                  all         25         51      0.716       0.88      0.849      0.462
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     16/149     1.91G   0.03718   0.01575  0.001615        41       416: 100% 16/16 [00:02<00:00,  7.28it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.23it/s]
#                  all         25         51       0.83       0.95      0.932      0.519
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     17/149     1.91G   0.03865   0.01443  0.001208        44       416: 100% 16/16 [00:02<00:00,  7.18it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.15it/s]
#                  all         25         51      0.941      0.925      0.959      0.427
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     18/149     1.91G   0.03648   0.01554  0.001525        46       416: 100% 16/16 [00:02<00:00,  7.18it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.20it/s]
#                  all         25         51      0.933      0.946      0.952      0.527
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     19/149     1.91G   0.03458   0.01543   0.00139        46       416: 100% 16/16 [00:02<00:00,  7.28it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.15it/s]
#                  all         25         51      0.967      0.946      0.963      0.575
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     20/149     1.91G   0.03656   0.01616   0.00128        65       416: 100% 16/16 [00:02<00:00,  7.34it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.98it/s]
#                  all         25         51      0.991      0.887      0.944      0.585
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     21/149     1.91G    0.0373   0.01484  0.001446        51       416: 100% 16/16 [00:02<00:00,  7.27it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.85it/s]
#                  all         25         51      0.948      0.957       0.96      0.573
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     22/149     1.91G   0.03488   0.01485  0.001319        50       416: 100% 16/16 [00:02<00:00,  7.28it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.84it/s]
#                  all         25         51      0.934      0.963      0.956      0.566
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     23/149     1.91G    0.0357   0.01577  0.001753        71       416: 100% 16/16 [00:02<00:00,  7.12it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.88it/s]
#                  all         25         51      0.954      0.963      0.961      0.587
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     24/149     1.91G   0.03315   0.01385  0.001084        45       416: 100% 16/16 [00:02<00:00,  7.20it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.09it/s]
#                  all         25         51      0.955      0.963      0.965      0.584
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     25/149     1.91G   0.03307    0.0147 0.0008443        47       416: 100% 16/16 [00:03<00:00,  4.73it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.06it/s]
#                  all         25         51      0.894      0.917      0.925      0.606
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     26/149     1.91G   0.03298   0.01484  0.001055        35       416: 100% 16/16 [00:02<00:00,  7.20it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.87it/s]
#                  all         25         51      0.903      0.905      0.934       0.55
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     27/149     1.91G   0.03237   0.01567  0.000993        53       416: 100% 16/16 [00:02<00:00,  7.23it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.82it/s]
#                  all         25         51      0.909      0.912      0.931      0.547
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     28/149     1.91G   0.03176   0.01456  0.001034        53       416: 100% 16/16 [00:02<00:00,  7.21it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.96it/s]
#                  all         25         51      0.908      0.912      0.936      0.646
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     29/149     1.91G   0.03162   0.01454  0.001117        53       416: 100% 16/16 [00:02<00:00,  7.18it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.01it/s]
#                  all         25         51      0.906      0.914      0.938      0.633
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     30/149     1.91G   0.03131   0.01505  0.001047        58       416: 100% 16/16 [00:02<00:00,  7.12it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.84it/s]
#                  all         25         51      0.926      0.963       0.96      0.592
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     31/149     1.91G   0.03186   0.01444 0.0008851        40       416: 100% 16/16 [00:02<00:00,  7.23it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.09it/s]
#                  all         25         51      0.912      0.959      0.955       0.61
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     32/149     1.91G   0.03182   0.01432 0.0008389        45       416: 100% 16/16 [00:02<00:00,  7.05it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.16it/s]
#                  all         25         51      0.889      0.917      0.951      0.611
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     33/149     1.91G   0.03016   0.01385  0.001073        59       416: 100% 16/16 [00:02<00:00,  7.23it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.09it/s]
#                  all         25         51      0.947      0.963       0.96      0.598
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     34/149     1.91G   0.03096   0.01465  0.001167        51       416: 100% 16/16 [00:02<00:00,  7.32it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.07it/s]
#                  all         25         51      0.938      0.963      0.959      0.599
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     35/149     1.91G   0.03275   0.01485 0.0009437        67       416: 100% 16/16 [00:02<00:00,  7.21it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.34it/s]
#                  all         25         51      0.929      0.963      0.958       0.62
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     36/149     1.91G   0.03028     0.014 0.0006635        46       416: 100% 16/16 [00:02<00:00,  7.24it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.02it/s]
#                  all         25         51       0.93      0.963      0.958      0.633
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     37/149     1.91G   0.03152    0.0137  0.001003        39       416: 100% 16/16 [00:02<00:00,  7.16it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.17it/s]
#                  all         25         51      0.886      0.917      0.933      0.562
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     38/149     1.91G   0.02854   0.01378 0.0008873        49       416: 100% 16/16 [00:02<00:00,  7.19it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.11it/s]
#                  all         25         51      0.889      0.917      0.915      0.575
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     39/149     1.91G   0.03026   0.01378 0.0008153        49       416: 100% 16/16 [00:02<00:00,  7.30it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.04it/s]
#                  all         25         51      0.891      0.917      0.914      0.594
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     40/149     1.91G   0.02922   0.01381 0.0009029        61       416: 100% 16/16 [00:02<00:00,  7.27it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.24it/s]
#                  all         25         51      0.912      0.912      0.922       0.48
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     41/149     1.91G   0.02974   0.01383  0.001014        57       416: 100% 16/16 [00:02<00:00,  7.26it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.93it/s]
#                  all         25         51      0.955      0.963      0.957      0.604
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     42/149     1.91G   0.02857   0.01374 0.0007098        51       416: 100% 16/16 [00:02<00:00,  7.17it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.13it/s]
#                  all         25         51      0.955      0.963      0.957      0.649
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     43/149     1.91G   0.02697   0.01306 0.0008809        41       416: 100% 16/16 [00:02<00:00,  7.11it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.67it/s]
#                  all         25         51       0.97      0.962      0.959      0.644
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     44/149     1.91G   0.02814    0.0138 0.0008102        56       416: 100% 16/16 [00:02<00:00,  7.13it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.53it/s]
#                  all         25         51      0.917      0.917      0.923      0.602
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     45/149     1.91G   0.02909   0.01439 0.0007075        59       416: 100% 16/16 [00:02<00:00,  7.12it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.03it/s]
#                  all         25         51      0.954      0.963      0.958      0.644
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     46/149     1.91G   0.02858   0.01298 0.0005746        50       416: 100% 16/16 [00:02<00:00,  7.27it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.20it/s]
#                  all         25         51      0.946      0.957      0.958      0.629
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     47/149     1.91G   0.02837   0.01295 0.0005662        52       416: 100% 16/16 [00:02<00:00,  7.24it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.19it/s]
#                  all         25         51      0.926      0.963      0.957      0.574
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     48/149     1.91G   0.02754   0.01356 0.0005755        45       416: 100% 16/16 [00:02<00:00,  7.13it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.08it/s]
#                  all         25         51      0.924      0.963      0.956      0.567
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     49/149     1.91G   0.02854    0.0126 0.0005707        57       416: 100% 16/16 [00:02<00:00,  7.30it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.20it/s]
#                  all         25         51      0.924      0.963      0.956       0.62
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     50/149     1.91G   0.02655   0.01278 0.0006102        49       416: 100% 16/16 [00:02<00:00,  7.17it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.18it/s]
#                  all         25         51      0.924      0.963      0.957      0.623
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     51/149     1.91G    0.0264   0.01328 0.0007627        41       416: 100% 16/16 [00:02<00:00,  7.19it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.83it/s]
#                  all         25         51      0.878      0.917      0.904      0.575
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     52/149     1.91G   0.02836   0.01347 0.0006742        52       416: 100% 16/16 [00:02<00:00,  7.05it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.92it/s]
#                  all         25         51      0.873      0.916       0.92      0.542
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     53/149     1.91G   0.02692   0.01264 0.0005319        39       416: 100% 16/16 [00:02<00:00,  7.16it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.20it/s]
#                  all         25         51      0.882      0.917      0.921      0.523
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     54/149     1.91G   0.02577   0.01248  0.000614        49       416: 100% 16/16 [00:02<00:00,  7.06it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.17it/s]
#                  all         25         51      0.944       0.95      0.961       0.62
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     55/149     1.91G   0.02646    0.0133  0.000526        45       416: 100% 16/16 [00:02<00:00,  7.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.99it/s]
#                  all         25         51      0.943      0.959       0.96      0.584
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     56/149     1.91G   0.02712    0.0127 0.0005543        38       416: 100% 16/16 [00:02<00:00,  7.20it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.93it/s]
#                  all         25         51      0.903      0.914      0.914      0.584
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     57/149     1.91G    0.0269   0.01325 0.0005348        49       416: 100% 16/16 [00:02<00:00,  7.22it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.85it/s]
#                  all         25         51       0.89      0.917      0.921      0.615
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     58/149     1.91G    0.0258   0.01289 0.0005279        47       416: 100% 16/16 [00:02<00:00,  7.29it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.89it/s]
#                  all         25         51       0.93      0.963      0.956      0.635
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     59/149     1.91G   0.02559   0.01311  0.000494        49       416: 100% 16/16 [00:02<00:00,  7.16it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.98it/s]
#                  all         25         51      0.928      0.959      0.957      0.646
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     60/149     1.91G   0.02575   0.01374 0.0005289        52       416: 100% 16/16 [00:02<00:00,  7.18it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.03it/s]
#                  all         25         51      0.927       0.96      0.957      0.598
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     61/149     1.91G   0.02517   0.01313   0.00045        47       416: 100% 16/16 [00:02<00:00,  7.18it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.90it/s]
#                  all         25         51      0.927      0.963      0.959      0.579
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     62/149     1.91G   0.02509   0.01274 0.0004404        60       416: 100% 16/16 [00:03<00:00,  4.66it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.82it/s]
#                  all         25         51      0.931      0.963      0.964      0.624
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     63/149     1.91G   0.02515   0.01256 0.0004522        47       416: 100% 16/16 [00:02<00:00,  7.11it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.09it/s]
#                  all         25         51      0.924      0.963      0.964      0.609
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     64/149     1.91G   0.02523   0.01257 0.0004847        53       416: 100% 16/16 [00:02<00:00,  7.14it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.07it/s]
#                  all         25         51      0.934      0.963      0.965      0.631
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     65/149     1.91G   0.02415   0.01221 0.0004549        41       416: 100% 16/16 [00:02<00:00,  7.22it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.20it/s]
#                  all         25         51      0.936      0.963      0.962      0.613
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     66/149     1.91G   0.02607   0.01261   0.00065        49       416: 100% 16/16 [00:02<00:00,  7.21it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.07it/s]
#                  all         25         51      0.885      0.917      0.928      0.609
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     67/149     1.91G   0.02481   0.01272 0.0005462        35       416: 100% 16/16 [00:02<00:00,  6.43it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.98it/s]
#                  all         25         51       0.92      0.951      0.957      0.575
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     68/149     1.91G   0.02399   0.01228 0.0004286        49       416: 100% 16/16 [00:02<00:00,  5.91it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.30it/s]
#                  all         25         51      0.963      0.935       0.96       0.58
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     69/149     1.91G   0.02567   0.01332 0.0004066        45       416: 100% 16/16 [00:02<00:00,  6.45it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.22it/s]
#                  all         25         51      0.894      0.917      0.918       0.52
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     70/149     1.91G   0.02467   0.01205 0.0005389        40       416: 100% 16/16 [00:02<00:00,  7.03it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.45it/s]
#                  all         25         51      0.958      0.963      0.961      0.609
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     71/149     1.91G   0.02418   0.01276 0.0003979        48       416: 100% 16/16 [00:02<00:00,  6.97it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.97it/s]
#                  all         25         51      0.957      0.963      0.963      0.588
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     72/149     1.91G   0.02528   0.01356 0.0004074        62       416: 100% 16/16 [00:02<00:00,  7.29it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.06it/s]
#                  all         25         51      0.959      0.963      0.965      0.605
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     73/149     1.91G   0.02438   0.01234  0.000441        43       416: 100% 16/16 [00:02<00:00,  7.28it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.98it/s]
#                  all         25         51      0.963      0.963      0.965      0.644
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     74/149     1.91G    0.0251   0.01305 0.0004993        48       416: 100% 16/16 [00:02<00:00,  7.21it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.48it/s]
#                  all         25         51      0.967      0.963      0.962      0.614
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     75/149     1.91G   0.02436    0.0113 0.0004835        41       416: 100% 16/16 [00:02<00:00,  7.06it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.90it/s]
#                  all         25         51      0.948       0.95      0.963      0.615
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     76/149     1.91G   0.02322   0.01295 0.0004555        52       416: 100% 16/16 [00:02<00:00,  7.23it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.07it/s]
#                  all         25         51      0.948       0.95      0.963       0.61
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     77/149     1.91G   0.02279   0.01222 0.0004256        58       416: 100% 16/16 [00:02<00:00,  6.03it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.80it/s]
#                  all         25         51      0.908      0.917      0.921      0.633
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     78/149     1.91G   0.02269   0.01201  0.000339        56       416: 100% 16/16 [00:02<00:00,  6.92it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.19it/s]
#                  all         25         51      0.945      0.963      0.963       0.62
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     79/149     1.91G   0.02352   0.01231  0.000342        57       416: 100% 16/16 [00:02<00:00,  7.11it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.86it/s]
#                  all         25         51      0.945      0.963      0.961      0.648
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     80/149     1.91G   0.02304   0.01238 0.0003873        43       416: 100% 16/16 [00:02<00:00,  7.13it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.96it/s]
#                  all         25         51      0.942      0.963       0.96      0.617
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     81/149     1.91G   0.02286   0.01237 0.0003833        53       416: 100% 16/16 [00:02<00:00,  7.11it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.06it/s]
#                  all         25         51      0.942      0.963      0.959      0.604
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     82/149     1.91G   0.02344   0.01283  0.000318        42       416: 100% 16/16 [00:02<00:00,  7.00it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.47it/s]
#                  all         25         51      0.902      0.911      0.912      0.594
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     83/149     1.91G   0.02376   0.01227 0.0004122        51       416: 100% 16/16 [00:02<00:00,  7.34it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.85it/s]
#                  all         25         51      0.885      0.917      0.919       0.59
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     84/149     1.91G   0.02361   0.01209 0.0003326        43       416: 100% 16/16 [00:02<00:00,  7.00it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.01it/s]
#                  all         25         51      0.964      0.934      0.959      0.599
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     85/149     1.91G   0.02301   0.01202 0.0003343        45       416: 100% 16/16 [00:02<00:00,  6.79it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.99it/s]
#                  all         25         51      0.919      0.955      0.949      0.602
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     86/149     1.91G   0.02323   0.01226 0.0003207        51       416: 100% 16/16 [00:02<00:00,  7.11it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.90it/s]
#                  all         25         51      0.895      0.917       0.92      0.576
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     87/149     1.91G   0.02257   0.01208 0.0004037        55       416: 100% 16/16 [00:02<00:00,  7.28it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.73it/s]
#                  all         25         51      0.896      0.917       0.94      0.611
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     88/149     1.91G   0.02332   0.01154 0.0003793        55       416: 100% 16/16 [00:02<00:00,  7.24it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  3.95it/s]
#                  all         25         51      0.906      0.917       0.92      0.594
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     89/149     1.91G   0.02298   0.01188 0.0003427        43       416: 100% 16/16 [00:02<00:00,  5.96it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.68it/s]
#                  all         25         51      0.956      0.963      0.965      0.627
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     90/149     1.91G   0.02173   0.01197 0.0003114        44       416: 100% 16/16 [00:02<00:00,  7.27it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.92it/s]
#                  all         25         51      0.952      0.963      0.965      0.623
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     91/149     1.91G   0.02192   0.01147  0.000279        48       416: 100% 16/16 [00:02<00:00,  7.16it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.05it/s]
#                  all         25         51      0.951      0.963      0.964       0.61
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     92/149     1.91G   0.02272   0.01217 0.0002953        43       416: 100% 16/16 [00:02<00:00,  7.20it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.11it/s]
#                  all         25         51      0.954      0.963      0.964      0.626
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     93/149     1.91G   0.02219   0.01136 0.0002755        41       416: 100% 16/16 [00:02<00:00,  7.01it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.94it/s]
#                  all         25         51      0.955      0.963      0.965      0.638
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     94/149     1.91G   0.02141   0.01153 0.0002725        49       416: 100% 16/16 [00:02<00:00,  7.08it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.92it/s]
#                  all         25         51      0.957      0.961      0.965      0.636
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     95/149     1.91G   0.02183   0.01135 0.0002563        39       416: 100% 16/16 [00:02<00:00,  7.08it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.95it/s]
#                  all         25         51      0.956      0.963      0.963      0.628
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     96/149     1.91G   0.02166   0.01132  0.000269        42       416: 100% 16/16 [00:02<00:00,  6.99it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.07it/s]
#                  all         25         51      0.912      0.917      0.923      0.613
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     97/149     1.91G   0.02242   0.01146 0.0002643        35       416: 100% 16/16 [00:02<00:00,  7.15it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.87it/s]
#                  all         25         51      0.908      0.917       0.92      0.599
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     98/149     1.91G   0.02142   0.01126 0.0002271        46       416: 100% 16/16 [00:02<00:00,  7.18it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.04it/s]
#                  all         25         51      0.956      0.963      0.962      0.634
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     99/149     1.91G    0.0211    0.0109 0.0002348        52       416: 100% 16/16 [00:02<00:00,  7.05it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.93it/s]
#                  all         25         51      0.954      0.963      0.962      0.613
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    100/149     1.91G   0.02091   0.01152 0.0002238        53       416: 100% 16/16 [00:02<00:00,  7.21it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.71it/s]
#                  all         25         51      0.956      0.963      0.961      0.604
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    101/149     1.91G   0.02223   0.01194 0.0002326        39       416: 100% 16/16 [00:02<00:00,  7.20it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.84it/s]
#                  all         25         51      0.959      0.962      0.961      0.612
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    102/149     1.91G   0.02158   0.01146 0.0002648        46       416: 100% 16/16 [00:02<00:00,  7.15it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.95it/s]
#                  all         25         51      0.958      0.963      0.961      0.607
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    103/149     1.91G    0.0205   0.01144 0.0002322        45       416: 100% 16/16 [00:02<00:00,  7.19it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.99it/s]
#                  all         25         51      0.957       0.96      0.961      0.615
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    104/149     1.91G   0.02167   0.01103 0.0004034        54       416: 100% 16/16 [00:02<00:00,  7.11it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.09it/s]
#                  all         25         51      0.956      0.959      0.961      0.627
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    105/149     1.91G   0.02098   0.01158 0.0002813        40       416: 100% 16/16 [00:02<00:00,  7.26it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.06it/s]
#                  all         25         51      0.942      0.963       0.96      0.626
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    106/149     1.91G   0.02087   0.01154 0.0002905        49       416: 100% 16/16 [00:02<00:00,  7.03it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.95it/s]
#                  all         25         51      0.901      0.917      0.911      0.624
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    107/149     1.91G   0.02117    0.0117 0.0002439        40       416: 100% 16/16 [00:02<00:00,  7.24it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.98it/s]
#                  all         25         51      0.917      0.914      0.912      0.592
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
# ...
#                  all         25         51      0.898      0.905      0.915      0.601
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    111/149     1.91G   0.02039   0.01178 0.0002115        52       416: 100% 16/16 [00:02<00:00,  7.16it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.57it/s]
#                  all         25         51      0.896      0.917      0.916      0.616
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    112/149     1.91G   0.02014   0.01121  0.000276        46       416: 100% 16/16 [00:02<00:00,  6.45it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  3.99it/s]
#                  all         25         51      0.954      0.963      0.962      0.638
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    113/149     1.91G   0.02072   0.01167 0.0001925        46       416: 100% 16/16 [00:02<00:00,  5.55it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.33it/s]
#                  all         25         51      0.914      0.917      0.911      0.625
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    114/149     1.91G   0.01972   0.01192 0.0002827        39       416: 100% 16/16 [00:02<00:00,  7.19it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.66it/s]
#                  all         25         51      0.917      0.917       0.91      0.634
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    115/149     1.91G   0.01986   0.01159 0.0001869        54       416: 100% 16/16 [00:02<00:00,  7.19it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.02it/s]
#                  all         25         51      0.914      0.917      0.912      0.605
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    116/149     1.91G   0.02004   0.01208 0.0002668        60       416: 100% 16/16 [00:02<00:00,  7.19it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.87it/s]
#                  all         25         51      0.958      0.963      0.963      0.638
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    117/149     1.91G   0.02041   0.01171 0.0003001        49       416: 100% 16/16 [00:02<00:00,  7.12it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.14it/s]
#                  all         25         51      0.957      0.963      0.963      0.645
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    118/149     1.91G   0.02014   0.01138 0.0002035        48       416: 100% 16/16 [00:02<00:00,  7.20it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.06it/s]
#                  all         25         51      0.957      0.963      0.961      0.644
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    119/149     1.91G   0.01993   0.01141 0.0002156        46       416: 100% 16/16 [00:02<00:00,  7.26it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.86it/s]
#                  all         25         51      0.957      0.963      0.961      0.635
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    120/149     1.91G   0.02056   0.01092 0.0001644        49       416: 100% 16/16 [00:02<00:00,  7.16it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.96it/s]
#                  all         25         51      0.913      0.917       0.92      0.611
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    121/149     1.91G   0.02002   0.01211 0.0001882        63       416: 100% 16/16 [00:02<00:00,  7.26it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.15it/s]
#                  all         25         51      0.914      0.917      0.917      0.622
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    122/149     1.91G   0.02023   0.01112 0.0001668        48       416: 100% 16/16 [00:02<00:00,  7.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.77it/s]
#                  all         25         51      0.958      0.963      0.962      0.629
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    123/149     1.91G   0.01988   0.01126 0.0002755        43       416: 100% 16/16 [00:02<00:00,  7.20it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.00it/s]
#                  all         25         51      0.957      0.963      0.963      0.654
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    124/149     1.91G   0.01937   0.01114 0.0001652        36       416: 100% 16/16 [00:02<00:00,  7.28it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.09it/s]
#                  all         25         51      0.957      0.963      0.964      0.654
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    125/149     1.91G    0.0192   0.01093 0.0001409        45       416: 100% 16/16 [00:02<00:00,  7.04it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.77it/s]
#                  all         25         51      0.956      0.963      0.964      0.653
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    126/149     1.91G   0.01959   0.01095 0.0002433        49       416: 100% 16/16 [00:02<00:00,  7.24it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.01it/s]
#                  all         25         51      0.956      0.963      0.962      0.654
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    127/149     1.91G   0.01984   0.01137 0.0001441        49       416: 100% 16/16 [00:02<00:00,  7.27it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.60it/s]
#                  all         25         51      0.956      0.963      0.964      0.609
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    128/149     1.91G   0.01892   0.01151  0.000149        46       416: 100% 16/16 [00:02<00:00,  7.05it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.05it/s]
#                  all         25         51      0.955      0.963      0.963      0.608
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    129/149     1.91G   0.01857   0.01067 0.0001276        54       416: 100% 16/16 [00:02<00:00,  7.22it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.02it/s]
#                  all         25         51      0.914      0.917      0.912      0.596
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    130/149     1.91G   0.01802    0.0108 0.0001231        47       416: 100% 16/16 [00:02<00:00,  7.29it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.91it/s]
#                  all         25         51      0.913      0.917      0.912      0.622
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    131/149     1.91G   0.01887   0.01195 0.0001397        47       416: 100% 16/16 [00:02<00:00,  7.14it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.10it/s]
#                  all         25         51      0.955      0.963      0.963      0.633
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    132/149     1.91G   0.01809   0.01098 0.0001288        37       416: 100% 16/16 [00:02<00:00,  7.15it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.02it/s]
#                  all         25         51      0.953      0.963      0.964      0.643
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    133/149     1.91G   0.01918   0.01131 0.0001265        52       416: 100% 16/16 [00:02<00:00,  7.07it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.34it/s]
#                  all         25         51      0.911      0.917       0.91      0.631
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    134/149     1.91G   0.01874    0.0116 0.0002976        44       416: 100% 16/16 [00:02<00:00,  7.30it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.96it/s]
#                  all         25         51      0.914      0.917       0.91      0.626
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    135/149     1.91G   0.01844   0.01097  0.000112        53       416: 100% 16/16 [00:02<00:00,  7.23it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.79it/s]
#                  all         25         51      0.959      0.961      0.964      0.638
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    136/149     1.91G   0.01896   0.01094 0.0001506        46       416: 100% 16/16 [00:02<00:00,  7.17it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.03it/s]
#                  all         25         51      0.959      0.962      0.963      0.633
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    137/149     1.91G   0.01905   0.01098 0.0001135        52       416: 100% 16/16 [00:02<00:00,  7.08it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.70it/s]
#                  all         25         51      0.956      0.963      0.964      0.644
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    138/149     1.91G   0.01889   0.01083 0.0001297        52       416: 100% 16/16 [00:02<00:00,  7.11it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.80it/s]
#                  all         25         51      0.956      0.963      0.963      0.629
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    139/149     1.91G   0.01777   0.01136 0.0001537        47       416: 100% 16/16 [00:02<00:00,  7.11it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.63it/s]
#                  all         25         51      0.956      0.963      0.963      0.634
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    140/149     1.91G   0.01853   0.01096 0.0001481        51       416: 100% 16/16 [00:02<00:00,  7.03it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.03it/s]
#                  all         25         51      0.956      0.963      0.963      0.654
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    141/149     1.91G   0.01863   0.01107 0.0001301        51       416: 100% 16/16 [00:02<00:00,  7.12it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.88it/s]
#                  all         25         51      0.957      0.963      0.963      0.633
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    142/149     1.91G    0.0186   0.01076 0.0001811        48       416: 100% 16/16 [00:02<00:00,  7.09it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.93it/s]
#                  all         25         51      0.957      0.963      0.962      0.637
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    143/149     1.91G   0.01811   0.01096 0.0001053        44       416: 100% 16/16 [00:02<00:00,  7.18it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.12it/s]
#                  all         25         51      0.956      0.963      0.963      0.629
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    144/149     1.91G   0.01912   0.01074 0.0002123        53       416: 100% 16/16 [00:02<00:00,  7.07it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.22it/s]
#                  all         25         51      0.957      0.963      0.963      0.628
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    145/149     1.91G   0.01778   0.01063 0.0001504        56       416: 100% 16/16 [00:02<00:00,  7.16it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.96it/s]
#                  all         25         51      0.956      0.963      0.963      0.624
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    146/149     1.91G   0.01834   0.01116 0.0001007        49       416: 100% 16/16 [00:02<00:00,  7.21it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.02it/s]
#                  all         25         51      0.913      0.917      0.914      0.626
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    147/149     1.91G    0.0181   0.01164 0.0001296        39       416: 100% 16/16 [00:02<00:00,  7.23it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.70it/s]
#                  all         25         51      0.914      0.917       0.91      0.615
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    148/149     1.91G   0.01841   0.01092 0.0001154        49       416: 100% 16/16 [00:02<00:00,  7.06it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.18it/s]
#                  all         25         51      0.913      0.917      0.919      0.629
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    149/149     1.91G   0.01835   0.01041  0.000109        42       416: 100% 16/16 [00:02<00:00,  7.12it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.69it/s]
#                  all         25         51      0.956      0.963      0.963       0.64
#
# 150 epochs completed in 0.119 hours.
# Optimizer stripped from runs/train/exp/weights/last.pt, 14.3MB
# Optimizer stripped from runs/train/exp/weights/best.pt, 14.3MB
#
# Validating runs/train/exp/weights/best.pt...
# Fusing layers...
# Model summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.67it/s]
#                  all         25         51      0.957      0.963      0.963      0.654
#          Aiman-Barai         25         11      0.945          1      0.995      0.732
#               Others         25         40       0.97      0.925      0.932      0.577
# Results saved to runs/train/exp

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source {dataset.location}/test/images
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/yolov5/MukaMukaBarai-1/MukaMukaBarai-1/test/images, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-347-g7b9cc32 Python-3.7.13 torch-1.12.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/13 /content/yolov5/MukaMukaBarai-1/MukaMukaBarai-1/test/images/AimanC_0032_png.rf.d2a7df6ffd10b8f0286390a7abba668b.jpg: 416x416 1 Aiman-Barai, Done. (0.008s)
# image 2/13 /content/yolov5/MukaMukaBarai-1/MukaMukaBarai-1/test/images/AimanC_0037_png.rf.bed05e403183c16282eecb4e30e8225b.jpg: 416x416 1 Aiman-Barai, Done. (0.008s)
# image 3/13 /content/yolov5/MukaMukaBarai-1/MukaMukaBarai-1/test/images/AimanC_0048_png.rf.3f9f889bc05b6859b9864c2dac35e9d8.jpg: 416x416 1 Aiman-Barai, Done. (0.008s)
# image 4/13 /content/yolov5/MukaMukaBarai-1/MukaMukaBarai-1/test/images/AimanC_0051_png.rf.20a8ecabae2d2c0a37af19494f06baa1.jpg: 416x416 1 Aiman-Barai, Done. (0.008s)
# image 5/13 /content/yolov5/MukaMukaBarai-1/MukaMukaBarai-1/test/images/Aiman_0040_png.rf.709aa1b8907a2cd9abc45da4ea6d2d2d.jpg: 416x416 1 Aiman-Barai, 1 Others, Done. (0.008s)
# image 6/13 /content/yolov5/MukaMukaBarai-1/MukaMukaBarai-1/test/images/Aiman_0041_png.rf.f996a6a71722b1bc217caccc2204b7eb.jpg: 416x416 1 Aiman-Barai, 1 Others, Done. (0.008s)
# image 7/13 /content/yolov5/MukaMukaBarai-1/MukaMukaBarai-1/test/images/Aiman_0057_png.rf.bb52657995108a12aeeccad416506043.jpg: 416x416 1 Aiman-Barai, 1 Others, Done. (0.008s)
# image 8/13 /content/yolov5/MukaMukaBarai-1/MukaMukaBarai-1/test/images/O1_0015_png.rf.4a7012b38e75451db4c931164fcc87be.jpg: 416x416 2 Otherss, Done. (0.008s)
# image 9/13 /content/yolov5/MukaMukaBarai-1/MukaMukaBarai-1/test/images/O1_0017_png.rf.1994711705bfc99606618e97ea698c55.jpg: 416x416 2 Otherss, Done. (0.008s)
# image 10/13 /content/yolov5/MukaMukaBarai-1/MukaMukaBarai-1/test/images/O2_0095_png.rf.1af6b735ded5a186953d98b176b7f4b1.jpg: 416x416 2 Otherss, Done. (0.008s)
# image 11/13 /content/yolov5/MukaMukaBarai-1/MukaMukaBarai-1/test/images/O2_0103_png.rf.55619d4b30ebcf3291e6038e65e735b1.jpg: 416x416 2 Otherss, Done. (0.008s)
# image 12/13 /content/yolov5/MukaMukaBarai-1/MukaMukaBarai-1/test/images/O2_0106_png.rf.a356a0c85573f00f8fd227cb07c0ebda.jpg: 416x416 2 Otherss, Done. (0.012s)
# image 13/13 /content/yolov5/MukaMukaBarai-1/MukaMukaBarai-1/test/images/O2_0122_png.rf.aad782bd3e6649722dc414d562156b55.jpg: 416x416 3 Otherss, Done. (0.008s)
# Speed: 0.3ms pre-process, 8.3ms inference, 0.9ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/exp

# %%
#display inference on ALL test images

import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/yolov5/yolov5/runs/detect/exp/*.jpg'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")

# %% [markdown]
# **Model & Video**
# https://drive.google.com/drive/folders/1WlzDCCxrg98PmZXC85jkh26V4jTAbMVo?usp=sharing
